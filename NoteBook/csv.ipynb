# %%
import glob
import pandas as pd

# Get all cleaned CSV files
csv_files = glob.glob('C:\\Users\\Admin\\Documents\\amazon\\Clean_CSV\\*.csv')

# Merge all files
df = pd.concat(
    [pd.read_csv(file) for file in csv_files],
    ignore_index=True
)

# Check merged dataset
print(df.shape)
print(df.head())

# Save merged dataset
df.to_csv(
    'amazon_india_merged_dataset.csv',
    index=False
)

print("All CSV files merged successfully!")
# Out:
# (791944, 36)
#       transaction_id  order_date         customer_id   product_id  \
# 0  TXN_2015_00000001  2015-01-25  CUST_2015_00003884  PROD_000021
# 1  TXN_2015_00000002  2015-05-01  CUST_2015_00011709  PROD_000055
# 2  TXN_2015_00000003  2015-01-24  CUST_2015_00004782  PROD_000039
# 3  TXN_2015_00000004  2015-01-28  CUST_2015_00008105  PROD_000085
# 4  TXN_2015_00000005  2015-01-31  CUST_2015_00002955  PROD_000055
#
#                            product_name     category  subcategory     brand  \
# 0          Samsung Galaxy S6 16GB Black  Electronics  Smartphones   Samsung
# 1          OnePlus OnePlus 2 16GB White  Electronics  Smartphones   OnePlus
# 2      Samsung Galaxy Note 5 64GB Black  Electronics  Smartphones   Samsung
# 3  Motorola Moto G (3rd Gen) 16GB Black  Electronics  Smartphones  Motorola
# 4          OnePlus OnePlus 2 16GB White  Electronics  Smartphones   OnePlus
#
#    original_price_inr  discount_percent  ...  customer_rating  return_status  \
# 0           123614.29             27.91  ...              5.0      Delivered
# 1            54731.86              0.00  ...              4.5      Delivered
# 2            97644.25             46.93  ...              NaN      Delivered
# 3            46458.94              0.00  ...              3.0      Delivered
# 4            54731.86              0.00  ...              4.0      Delivered
#
#    order_month  order_year  order_quarter product_weight_kg is_prime_eligible  \
# 0            1        2015              1              0.19              True
# 1            1        2015              1              0.20              True
# 2            1        2015              1              0.17              True
# 3            1        2015              1              0.22              True
# 4            1        2015              1              0.20              True
#
#   product_rating base_price_2015_x base_price_2015_y
# 0            4.7               NaN               NaN
# 1            4.1               NaN               NaN
# 2            3.3               NaN               NaN
# 3            3.5               NaN               NaN
# 4            4.1               NaN               NaN
#
# [5 rows x 36 columns]
# All CSV files merged successfully!

# %%
df.columns
# Out:
# Index(['transaction_id', 'order_date', 'customer_id', 'product_id',
#        'product_name', 'category', 'subcategory', 'brand',
#        'original_price_inr', 'discount_percent', 'discounted_price_inr',
#        'quantity', 'subtotal_inr', 'delivery_charges', 'final_amount_inr',
#        'customer_city', 'customer_state', 'customer_tier',
#        'customer_spending_tier', 'customer_age_group', 'payment_method',
#        'delivery_days', 'delivery_type', 'is_prime_member', 'is_festival_sale',
#        'festival_name', 'customer_rating', 'return_status', 'order_month',
#        'order_year', 'order_quarter', 'product_weight_kg', 'is_prime_eligible',
#        'product_rating', 'base_price_2015_x', 'base_price_2015_y', 'year'],
#       dtype='str')

# %%
df['order_date'] = pd.to_datetime(
    df['order_date'],
    errors='coerce',
    dayfirst=True
)

df['year'] = df['order_date'].dt.year
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17216\1696132252.py:1: UserWarning: Parsing dates in %Y-%m-%d format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   df['order_date'] = pd.to_datetime(

# %%
df['year'].unique()
# Out:
# array([2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025],
#       dtype=int32)

# %%
df.dtypes
# Out:
# transaction_id                       str
# order_date                datetime64[us]
# customer_id                          str
# product_id                           str
# product_name                         str
# category                             str
# subcategory                          str
# brand                                str
# original_price_inr               float64
# discount_percent                 float64
# discounted_price_inr             float64
# quantity                           int64
# subtotal_inr                     float64
# delivery_charges                 float64
# final_amount_inr                 float64
# customer_city                        str
# customer_state                       str
# customer_tier                        str
# customer_spending_tier               str
# customer_age_group                   str
# payment_method                       str
# delivery_days                      int64
# delivery_type                        str
# is_prime_member                     bool
# is_festival_sale                    bool
# festival_name                        str
# customer_rating                  float64
# return_status                        str
# order_month                        int64
# order_year                         int64
# order_quarter                      int64
# product_weight_kg                float64
# is_prime_eligible                   bool
# product_rating                   float64
# base_price_2015_x                float64
# base_price_2015_y                float64
# year                               int32
# dtype: object

# %%
df['is_prime_eligible'].dtype
# Out:
# dtype('bool')

# %%
print(df['order_date'].min())
print(df['order_date'].max())

print(
    df['order_date']
    .dt.year
    .value_counts()
    .sort_index()
)
# Out:
# 2015-01-01 00:00:00
# 2025-12-31 00:00:00
# order_date
# 2015    33000
# 2016    38321
# 2017    53528
# 2018    68939
# 2019    84381
# 2020    99588
# 2021    95833
# 2022    91971
# 2023    88209
# 2024    84512
# 2025    53662
# Name: count, dtype: int64

# %%
check = (
    df.groupby(
        df['order_date'].dt.year
    )['final_amount_inr']
    .sum()
)

print(check)
# Out:
# order_date
# 2015    2.130499e+09
# 2016    2.493221e+09
# 2017    3.810509e+09
# 2018    5.025716e+09
# 2019    5.970644e+09
# 2020    8.225813e+09
# 2021    7.629816e+09
# 2022    5.916479e+09
# 2023    5.352998e+09
# 2024    4.746392e+09
# 2025    2.668559e+09
# Name: final_amount_inr, dtype: float64
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
